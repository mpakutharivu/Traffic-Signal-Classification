# %% [markdown]
# In this project, we will use Convolutional Neural Network to build train and test a traffic sign classification model. We will build this model using tensorflow and keras. It is a multiclass classification problem. This model can be used to make smarter cars.

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\madhu\anaconda3\lib\site-packages (1.8.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: black>=24.10.0 in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (0.1.14)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (23.1)
# Requirement already satisfied: protobuf in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (4.23.4)
# Requirement already satisfied: python-dateutil in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: six>=1.10 in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (4.65.0)
# Requirement already satisfied: types-requests in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\madhu\anaconda3\lib\site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\madhu\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\madhu\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\madhu\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\madhu\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (3.10.0)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\madhu\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\madhu\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (4.10.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\madhu\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.7)
# Requirement already satisfied: webencodings in c:\users\madhu\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\madhu\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\madhu\anaconda3\lib\site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhu\anaconda3\lib\site-packages (from requests->kaggle) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhu\anaconda3\lib\site-packages (from requests->kaggle) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\madhu\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %% [markdown]
# We will start by connecting to Kaggle using Kaggle API which can be downloaded from your Kaggle account's settings and uploading it here(upload box).

# %%
import os

# Path where kaggle.json is stored (Windows)
KAGGLE_CONFIG_DIR = r"C:\Users\madhu\.kaggle"

# Tell Kaggle where to find the API token
os.environ["KAGGLE_CONFIG_DIR"] = KAGGLE_CONFIG_DIR

print("KAGGLE_CONFIG_DIR set to:", os.environ["KAGGLE_CONFIG_DIR"])
# Out:
# KAGGLE_CONFIG_DIR set to: C:\Users\madhu\.kaggle

# %%
import subprocess

# Check Kaggle API installation
result = subprocess.run(
    ["kaggle", "--version"],
    capture_output=True,
    text=True
)

print(result.stdout)
# Out:
# Kaggle API 1.8.3

# %%
import os

BASE_DIR = "data"
RAW_DIR = os.path.join(BASE_DIR, "raw")
PROCESSED_DIR = os.path.join(BASE_DIR, "processed")

os.makedirs(RAW_DIR, exist_ok=True)
os.makedirs(PROCESSED_DIR, exist_ok=True)

print("Project folders created")
# Out:
# Project folders created

# %%
DATASET = "meowmeowmeowmeowmeow/gtsrb-german-traffic-sign"

subprocess.run(
    [
        "kaggle",
        "datasets",
        "download",
        "-d",
        DATASET,
        "-p",
        RAW_DIR
    ],
    check=True
)
# Out:
# CompletedProcess(args=['kaggle', 'datasets', 'download', '-d', 'meowmeowmeowmeowmeow/gtsrb-german-traffic-sign', '-p', 'data\\raw'], returncode=0)

# %%
# Extract the downloaded ZIP file
ZIP_PATH = os.path.join(RAW_DIR, "gtsrb-german-traffic-sign.zip")

with zipfile.ZipFile(ZIP_PATH, "r") as zip_ref:
    zip_ref.extractall(RAW_DIR)

print("Dataset downloaded and extracted successfully")
# Out:
# Dataset extracted successfully

# %%
# Importing libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
import random
from PIL import Image
from sklearn.model_selection import  train_test_split
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D

# %%
# Correct TEST dataset path
path = r"C:\Documents\Desktop\Uni sem\GITHUB PROJECTS\Traffic Signal Classification\Collab+Code\Collab Code\data\raw\Test"

plt.figure(figsize=(12,12))

for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()

    rand_img = imread(path + '/' + random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)

    plt.xlabel(rand_img.shape[1], fontsize=10)  # width
    plt.ylabel(rand_img.shape[0], fontsize=10)  # height

plt.show()

# %% [markdown]
# Visualizing some images of traffic sign from the test dataset. we can see here that the dimension of images are uneven.

# %%
import os
from matplotlib.image import imread

dim1 = []
dim2 = []

# Correct GTSRB training images path
train_path = r"C:\Documents\Desktop\Uni sem\GITHUB PROJECTS\Traffic Signal Classification\Collab+Code\Collab Code\data\raw\Train"

for i in range(43):
    class_folder = format(i)  # '00000', '00001', ..., '00042'
    labels = os.path.join(train_path, class_folder)

    image_path = os.listdir(labels)

    for x in image_path:
        img = imread(os.path.join(labels, x))
        dim1.append(img.shape[0])  # height
        dim2.append(img.shape[1])  # width

# %% [markdown]
# For further processing we will require the images of same dimension. So, we will start storing the dimension of all the images from training dataset from all 43 classes.

# %%
#Printing mean dimension of images
print("Dimension 1 Mean : ",np.mean(dim1), " Dimension 2 Mean : ",np.mean(dim2))
# Out:
# Dimension 1 Mean :  50.328929582493814  Dimension 2 Mean :  50.83587951745773

# %% [markdown]
# Now we will find out the mean value of both the dimensions and analyse them. Here, we can see that (50,50) is the average shape for all the images.

# %%
# Now we will reshape the images to (50,50)
images = []
label_id = []

for i in range(43):
    labels = r"C:\Documents\Desktop\Uni sem\GITHUB PROJECTS\Traffic Signal Classification\Collab+Code\Collab Code\data\raw\Train" + '/{0}'.format(i)
    image_path = os.listdir(labels)
    for x in image_path:
        img = Image.open(labels + '/' + x)
        img = img.resize((50,50))
        img = np.array(img)
        images.append(img)
        label_id.append(i)

# %% [markdown]
# Now we will reshape the images into (50,50) and also store their label ids.

# %%
#Converting images into numpy array
images = np.array(images)
#The pixel value of each image ranges between 0 and 255
#Dividing each image by 255 will scale the values between 0 and 1. This is also known as normalization.
images = images/255

# %% [markdown]
# Now we will convert all the images into numpy array and normalize them.

# %%
label_id = np.array(label_id)
label_id.shape
# Out:
# (39209,)

# %% [markdown]
# Storing the label ids into numpy array and printing the shape. Here we can observe that their are 39209 label ids.

# %%
images.shape
# Out:
# (39209, 50, 50, 3)

# %% [markdown]
# Checking the shape of the images. Here we can see that their are 39209 images with a shape of (50,50,3.)

# %% [markdown]
# Now we will observe images per class for checking whether the data is balanced or not. From the result we can say that data is balanced.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_id).value_counts()
label_counts.head()
# Out:
# 2     2250
# 1     2220
# 13    2160
# 12    2100
# 38    2070
# Name: count, dtype: int64

# %% [markdown]
# The next step would be to split the data into training and validation with 80% of training data and 20% of validation data.

# %%
#Splitting the data
x_train, x_val, y_train, y_val = train_test_split(images, label_id , test_size = 0.2, random_state = 42)

# %% [markdown]
# Converting the classes column into categorical using to_categorical() function.

# %%
#keras has a built-in function for one-hot encoding.
y_train_cat = to_categorical(y_train)
y_val_cat = to_categorical(y_val)

# %% [markdown]
# Defining the model architecture. In this we will define all the layers with their input shape kernel size, activation, etc.

# %%
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (3,3), input_shape = x_train.shape[1:], activation = 'relu', padding = 'same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(43, activation = 'softmax'))
# Out:
# WARNING:tensorflow:From c:\Users\madhu\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\madhu\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# Compiling the model using metrics, optimizer and loss as required and printing out the summary of the model.

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\madhu\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 64)        1792
#
#  max_pooling2d (MaxPooling2  (None, 25, 25, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 25, 25, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 128)               991360
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 1035627 (3.95 MB)
# Trainable params: 1035627 (3.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now we will fit the model and observe how our is getting trained on each epoch.

# %%
model.fit(x_train, y_train, epochs = 10, batch_size = 128, validation_data = (x_val, y_val), verbose = 2)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\madhu\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\madhu\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 246/246 - 174s - loss: 2.4589 - accuracy: 0.3256 - val_loss: 1.2286 - val_accuracy: 0.6943 - 174s/epoch - 708ms/step
# Epoch 2/10
# 246/246 - 202s - loss: 1.1547 - accuracy: 0.6357 - val_loss: 0.5139 - val_accuracy: 0.8730 - 202s/epoch - 821ms/step
# Epoch 3/10
# 246/246 - 252s - loss: 0.7885 - accuracy: 0.7456 - val_loss: 0.3321 - val_accuracy: 0.9388 - 252s/epoch - 1s/step
# Epoch 4/10
# 246/246 - 249s - loss: 0.6150 - accuracy: 0.7992 - val_loss: 0.2102 - val_accuracy: 0.9575 - 249s/epoch - 1s/step
# Epoch 5/10
# 246/246 - 239s - loss: 0.5278 - accuracy: 0.8280 - val_loss: 0.1841 - val_accuracy: 0.9665 - 239s/epoch - 971ms/step
# Epoch 6/10
# 246/246 - 68s - loss: 0.4515 - accuracy: 0.8536 - val_loss: 0.1346 - val_accuracy: 0.9776 - 68s/epoch - 276ms/step
# Epoch 7/10
# 246/246 - 67s - loss: 0.4045 - accuracy: 0.8682 - val_loss: 0.1309 - val_accuracy: 0.9788 - 67s/epoch - 273ms/step
# Epoch 8/10
# 246/246 - 67s - loss: 0.3715 - accuracy: 0.8784 - val_loss: 0.1050 - val_accuracy: 0.9841 - 67s/epoch - 272ms/step
# Epoch 9/10
# 246/246 - 68s - loss: 0.3453 - accuracy: 0.8861 - val_loss: 0.0955 - val_accuracy: 0.9841 - 68s/epoch - 277ms/step
# Epoch 10/10
# 246/246 - 68s - loss: 0.3117 - accuracy: 0.8987 - val_loss: 0.0714 - val_accuracy: 0.9850 - 68s/epoch - 276ms/step

# %% [markdown]
# Next we will visualize the accuracy and loss per epoch. For this we will store the model history in the pandas dataframe and plot them.

# %%
evaluation = pd.DataFrame(model.history.history)
evaluation[['accuracy', 'val_accuracy']].plot()
evaluation[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %% [markdown]
# Creating the variable which has path of test dataset. As we downloded the dataset we found out that their is a GT-final_test.csv file in the test images folder which cannot be processed. So, we will remove that file.

# %%
test_path = r"C:\Documents\Desktop\Uni sem\GITHUB PROJECTS\Traffic Signal Classification\Collab+Code\Collab Code\data\raw\Test"
file_path = os.path.join(test_path, 'GT-final_test.csv')

if os.path.exists(file_path):
    os.remove(file_path)
    print("File removed successfully")
else:
    print("File not found")
# Out:
# File removed successfully

# %% [markdown]
# Next step would we creating a function to resize the test images converting them into a numpy array and normalize them.

# %%
#defining a function that will scale images
from PIL import Image

def scaling(test_images, test_path):
    images = []

    image_path = test_images
    
    for x in image_path:
        img = Image.open(test_path + '/' + x)
        img = img.resize((50,50))
        img = np.array(img)
        images.append(img)

    #Converting images into numpy array
    images = np.array(images)
    #The pixel value of each image ranges between 0 and 255
    #Dividing each image by 255 will scale the values between 0 and 1. This is also known as normalization.
    images = images/255

    return images

# %% [markdown]
# Calling the above created function on test images.

# %%
test_images = scaling(sorted(os.listdir(test_path)),test_path)

# %% [markdown]
# Next we will read label ids from Test.csv and store the values of the class id in y_test variable.

# %%
test = pd.read_csv(r"C:\Documents\Desktop\Uni sem\GITHUB PROJECTS\Traffic Signal Classification\Collab+Code\Collab Code\data\raw\Test.csv")
y_test = test['ClassId'].values
y_test
# Out:
# array([16,  1, 38, ...,  6,  7, 10], dtype=int64)

# %% [markdown]
# Now we will use the model to make predictions on our test images and save them in y_pred.

# %%
import numpy as np

y_pred_probs = model.predict(test_images)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
# Out:
# 395/395 [==============================] - 6s 16ms/step

# %% [markdown]
# Storing the labels according to the image classes.

# %%
# Storing all lables
all_lables = ['Speed limit (20km/h)','Speed limit (30km/h)','Speed limit (50km/h)','Speed limit (60km/h)',
              'Speed limit (70km/h)','Speed limit (80km/h)','End of speed limit (80km/h)','Speed limit (100km/h)',
              'Speed limit (120km/h)','No passing','No passing for vechiles over 3.5 metric tons',
              'Right-of-way at the next intersection','Priority road','Yield','Stop','No vechiles',
              'Vechiles over 3.5 metric tons prohibited','No entry','General caution','Dangerous curve to the left',
              'Dangerous curve to the right','Double curve','Bumpy road','Slippery road','Road narrows on the right',
              'Road work','Traffic signals','Pedestrians','Children crossing','Bicycles crossing','Beware of ice/snow',
              'Wild animals crossing','End of all speed and passing limits','Turn right ahead','Turn left ahead',
              'Ahead only','Go straight or right','Go straight or left','Keep right','Keep left','Roundabout mandatory',
              'End of no passing','End of no passing by vechiles over 3.5 metric']

# %% [markdown]
# Let's visualize test image

# %%
# Visualize test image
img = Image.open(test_path + '/00001.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=42x45>

# %% [markdown]
# Finding out original label for the image above.

# %%
# Original label
print("Original label : ",all_lables[y_test[1]])
# Out:
# Original label :  Keep right

# %% [markdown]
# Finding out the predicted label for the image above.

# %%
idx = 1
print("Predicted label:", all_lables[y_pred_labels[idx]])
# Out:
# Predicted label: Speed limit (30km/h)

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# We started with downloading the dataset, preprocessing it, created the model and found out the predictions using the model. During preprocessing we found that this dataset has 43 classes. Model reached an accuracy of 95%+ in just 50 epochs, we can further optimize the model using hyper parameter tuning and reach a higher accuracy.

# %% [markdown]
# # Scope:

# %% [markdown]
# This model can be used in self driving cars which will enable them to automatically recognize traffic signs similarly the driver alert system inside cars will help and protect drivers by understanding the traffic signs around them.
